# %% [markdown]
# # Lab | Web Scraping Multiple Pages
#
# <br>
#
# <details><summary>▶ Taking into account following:</summary>
# <p>
#
#
# #### Business goal:
#
# Done in previous lab
#
# #### Instructions
#
# #### Prioritize the MVP
#
# MVP finished in previous lab
#
# #### Expand the project
#
# If you're done, you can try to expand the project on your own. Here are a few suggestions:
#
# - Find other lists of hot songs on the internet and scrape them too: having a bigger pool of songs will be awesome!
# - Apply the same logic to other "groups" of songs: the best songs from a decade or from a country / culture / language / genre.
# - Wikipedia maintains a large collection of lists of songs: https://en.wikipedia.org/wiki/Lists_of_songs
#
# #### Practice web scraping
#
# As you've seen, scraping the internet is a skill that can get you all sorts of information. Here are some little challenges that you can try to gain more experience in the field:
#
# - Retrieve an arbitrary Wikipedia page of "Python" and create a list of links on that page: `url ='https://en.wikipedia.org/wiki/Python'`
# - Find the number of titles that have changed in the United States Code since its last release point: `url = 'http://uscode.house.gov/download/download.shtml'`
# - Create a Python list with the top ten FBI's Most Wanted names: `url = 'https://www.fbi.gov/wanted/topten'`
# - Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe: `url = 'https://www.emsc-csem.org/Earthquake/'`
# - List all language names and number of related articles in the order they appear in [wikipedia.org](wikipedia.org): `url = 'https://www.wikipedia.org/'`
# - A list with the different kind of datasets available in [data.gov.uk](data.gov.uk): `url = 'https://data.gov.uk/'`
# - Display the top 10 languages by number of native speakers stored in a pandas dataframe: `url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'`
#
# </p>
# </details>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from random import randint  # for random wait time respectful scraping
from time import sleep      # sleep function

# %%
# using header to avoind 403 error, server thinks I am a just a user browsing
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

artist = []
song = []
years = range(1969, 2017)

for y in years:
    start_at= str(y)
    wait_time = randint(1,4)
    sleep(wait_time)
    url = "https://playback.fm/charts/top-100-songs/" + start_at 
    response = requests.get(url, headers=header)
    soup = BeautifulSoup(response.content, "html.parser")
    for i in soup.select("td:nth-child(2) > a"):
        i = i.get_text()
        i = i.replace('\n','')
        artist.append(i)    
    for i in soup.select("td.mobile-hide > a > span.song"):
        i = i.get_text()
        song.append(i) 
    print("processed:", url, "with wait time:", wait_time, "- songs:", len(song), "artists:", len(artist))
top_100 = pd.DataFrame({"song":song, "artist":artist})  
top_100.shape
# Out:
# processed: https://playback.fm/charts/top-100-songs/1969 with wait time: 1 - songs: 100 artists: 100
# processed: https://playback.fm/charts/top-100-songs/1970 with wait time: 3 - songs: 200 artists: 200
# processed: https://playback.fm/charts/top-100-songs/1971 with wait time: 1 - songs: 300 artists: 300
# processed: https://playback.fm/charts/top-100-songs/1972 with wait time: 1 - songs: 400 artists: 400
# processed: https://playback.fm/charts/top-100-songs/1973 with wait time: 1 - songs: 500 artists: 500
# processed: https://playback.fm/charts/top-100-songs/1974 with wait time: 4 - songs: 600 artists: 600
# processed: https://playback.fm/charts/top-100-songs/1975 with wait time: 3 - songs: 700 artists: 700
# processed: https://playback.fm/charts/top-100-songs/1976 with wait time: 4 - songs: 800 artists: 800
# processed: https://playback.fm/charts/top-100-songs/1977 with wait time: 4 - songs: 900 artists: 900
# processed: https://playback.fm/charts/top-100-songs/1978 with wait time: 1 - songs: 1000 artists: 1000
# processed: https://playback.fm/charts/top-100-songs/1979 with wait time: 1 - songs: 1100 artists: 1100
# processed: https://playback.fm/charts/top-100-songs/1980 with wait time: 2 - songs: 1200 artists: 1200
# processed: https://playback.fm/charts/top-100-songs/1981 with wait time: 2 - songs: 1300 artists: 1300
# processed: https://playback.fm/charts/top-100-songs/1982 with wait time: 2 - songs: 1400 artists: 1400
# processed: https://playback.fm/charts/top-100-songs/1983 with wait time: 2 - songs: 1500 artists: 1500
# processed: https://playback.fm/charts/top-100-songs/1984 with wait time: 4 - songs: 1600 artists: 1600
# processed: https://playback.fm/charts/top-100-songs/1985 with wait time: 1 - songs: 1700 artists: 1700
# processed: https://playback.fm/charts/top-100-songs/1986 with wait time: 4 - songs: 1800 artists: 1800
# processed: https://playback.fm/charts/top-100-songs/1987 with wait time: 1 - songs: 1900 artists: 1900
# processed: https://playback.fm/charts/top-100-songs/1988 with wait time: 3 - songs: 2000 artists: 2000
# processed: https://playback.fm/charts/top-100-songs/1989 with wait time: 2 - songs: 2100 artists: 2100
# processed: https://playback.fm/charts/top-100-songs/1990 with wait time: 4 - songs: 2200 artists: 2200
# processed: https://playback.fm/charts/top-100-songs/1991 with wait time: 2 - songs: 2300 artists: 2300
# processed: https://playback.fm/charts/top-100-songs/1992 with wait time: 1 - songs: 2400 artists: 2400
# processed: https://playback.fm/charts/top-100-songs/1993 with wait time: 3 - songs: 2500 artists: 2500
# processed: https://playback.fm/charts/top-100-songs/1994 with wait time: 2 - songs: 2600 artists: 2600
# processed: https://playback.fm/charts/top-100-songs/1995 with wait time: 3 - songs: 2699 artists: 2699
# processed: https://playback.fm/charts/top-100-songs/1996 with wait time: 1 - songs: 2799 artists: 2799
# processed: https://playback.fm/charts/top-100-songs/1997 with wait time: 2 - songs: 2899 artists: 2899
# processed: https://playback.fm/charts/top-100-songs/1998 with wait time: 4 - songs: 2999 artists: 2999
# processed: https://playback.fm/charts/top-100-songs/1999 with wait time: 1 - songs: 3099 artists: 3099
# processed: https://playback.fm/charts/top-100-songs/2000 with wait time: 1 - songs: 3199 artists: 3199
# processed: https://playback.fm/charts/top-100-songs/2001 with wait time: 4 - songs: 3299 artists: 3299
# processed: https://playback.fm/charts/top-100-songs/2002 with wait time: 1 - songs: 3399 artists: 3399
# processed: https://playback.fm/charts/top-100-songs/2003 with wait time: 3 - songs: 3499 artists: 3499
# processed: https://playback.fm/charts/top-100-songs/2004 with wait time: 3 - songs: 3599 artists: 3599
# processed: https://playback.fm/charts/top-100-songs/2005 with wait time: 2 - songs: 3699 artists: 3699
# processed: https://playback.fm/charts/top-100-songs/2006 with wait time: 1 - songs: 3799 artists: 3799
# processed: https://playback.fm/charts/top-100-songs/2007 with wait time: 2 - songs: 3899 artists: 3899
# processed: https://playback.fm/charts/top-100-songs/2008 with wait time: 4 - songs: 3999 artists: 3999
# processed: https://playback.fm/charts/top-100-songs/2009 with wait time: 1 - songs: 4099 artists: 4099
# processed: https://playback.fm/charts/top-100-songs/2010 with wait time: 3 - songs: 4199 artists: 4199
# processed: https://playback.fm/charts/top-100-songs/2011 with wait time: 4 - songs: 4299 artists: 4299
# processed: https://playback.fm/charts/top-100-songs/2012 with wait time: 3 - songs: 4399 artists: 4399
# processed: https://playback.fm/charts/top-100-songs/2013 with wait time: 4 - songs: 4498 artists: 4498
# processed: https://playback.fm/charts/top-100-songs/2014 with wait time: 2 - songs: 4597 artists: 4597
# processed: https://playback.fm/charts/top-100-songs/2015 with wait time: 4 - songs: 4697 artists: 4697
# processed: https://playback.fm/charts/top-100-songs/2016 with wait time: 4 - songs: 4797 artists: 4797
# (4797, 2)

# %%
top_100.head(60)
# Out:
#                                                 song  \
# 0                                           Get Back
# 1                                        Sugar Sugar
# 2             In the Year 2525 (Exordium & Terminus)
# 3                                   Honky Tonk Woman
# 4                                   Suspicious Minds
# 5                                      In the Ghetto
# 6                                      Come Together
# 7                          The Ballad of John & Yoko
# 8                                       Oh Happy Day
# 9                                   Crimson & Clover
# 10                      Aquarius/Let The Sunshine In
# 11                                        Proud Mary
# 12                          Je T'Aime (Moi Non Plus)
# 13                                             Dizzy
# 14                                   Bad Moon Rising
# 15                                         Something
# 16                                        Israelites
# 17                                Ob-La-Di, Ob-La-Da
# 18                                          Atlantis
# 19                             Build Me Up Buttercup
# 20                                         The Boxer
# 21                                 Stand By Your Man
# 22                                  I Started a Joke
# 23                                 Saved By the Bell
# 24                          Don't Forget to Remember
# 25                                          Touch Me
# 26                                              Hair
# 27                                Down On the Corner
# 28                               Give Peace a Chance
# 29                                Ob-La-Di, Ob-La-Da
# 30                                       Green River
# 31                   He Ain't Heavy, He's My Brother
# 32                                  Oh Well (Part 1)
# 33                    Yester-Me Yester-You Yesterday
# 34                                    Spinning Wheel
# 35                                           Goodbye
# 36                             Son of a Preacher Man
# 37                                     Sorry Suzanne
# 38                                Time of the Season
# 39                            Good Morning Starshine
# 40                                         Mendocino
# 41                                Wedding Bell Blues
# 42                               Everybody's Talkin'
# 43                     Where Do You Go to My Lovely?
# 44                                   A Boy Named Sue
# 45                                  Boom Bang-A-Bang
# 46                                     Lily the Pink
# 47                           Leaving, on a Jet Plane
# 48                                   Everyday People
# 49                                 Games People Play
# 50                      You've Made Me So Very Happy
# 51                                     Fortunate Son
# 52                                    Only One Woman
# 53                           I Can't Get Next to You
# 54  Sweet Caroline (Good Times Never Seemed So Good)
# 55                                 Don't Let Me Down
# 56                                              Jean
# 57                                      First of May
# 58                         Someday We'll Be Together
# 59                                            My Way
#
#                             artist
# 0                      The Beatles
# 1                          Archies
# 2                    Zager & Evans
# 3               The Rolling Stones
# 4                    Elvis Presley
# 5                    Elvis Presley
# 6                      The Beatles
# 7                      The Beatles
# 8            Edwin Hawkins Singers
# 9      Tommy James & the Shondells
# 10                 Fifth Dimension
# 11    Creedence Clearwater Revival
# 12  Jane Birkin & Serge Gainsbourg
# 13                       Tommy Roe
# 14    Creedence Clearwater Revival
# 15                     The Beatles
# 16                  Desmond Dekker
# 17                     The Beatles
# 18                         Donovan
# 19                 The Foundations
# 20               Simon & Garfunkel
# 21                   Tammy Wynette
# 22                        Bee Gees
# 23                      Robin Gibb
# 24                        Bee Gees
# 25                       The Doors
# 26                    The Cowsills
# 27    Creedence Clearwater Revival
# 28                     John Lennon
# 29                       Marmalade
# 30    Creedence Clearwater Revival
# 31                     The Hollies
# 32                   Fleetwood Mac
# 33                   Stevie Wonder
# 34             Blood Sweat & Tears
# 35                     Mary Hopkin
# 36               Dusty Springfield
# 37                     The Hollies
# 38                     The Zombies
# 39                          Oliver
# 40             Sir Douglas Quintet
# 41                 Fifth Dimension
# 42                   Harry Nilsson
# 43                  Peter Sarstedt
# 44                     Johnny Cash
# 45                            Lulu
# 46                    The Scaffold
# 47              Peter, Paul & Mary
# 48          Sly & The Family Stone
# 49                       Joe South
# 50             Blood Sweat & Tears
# 51    Creedence Clearwater Revival
# 52                     The Marbles
# 53                 The Temptations
# 54                    Neil Diamond
# 55                     The Beatles
# 56                          Oliver
# 57                        Bee Gees
# 58       Diana Ross & The Supremes
# 59                   Frank Sinatra

# %%
top_100[top_100.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [song, artist]
# Index: []
